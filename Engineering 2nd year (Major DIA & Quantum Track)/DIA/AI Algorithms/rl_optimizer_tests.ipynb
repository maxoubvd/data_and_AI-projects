# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
class TinyModel(nn.Module):


    def __init__(self, vocab_size, n_embd, n_heads, n_layers, dropout=0.1):
        super().__init__()
        # conversion tokken -> vector
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(64, n_embd)
        # cerveau simplifié pour aller plus vite
        self.net = nn.Sequential(nn.Linear(n_embd, n_embd), nn.ReLU(), nn.Linear(n_embd, n_embd), nn.Dropout(dropout))
        # sortie Vecteur -->  proba du prochain mot
        self.lm_head= nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)  # (B,T,n_embd)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))  # (T,n_embd)
        x = tok_emb + pos_emb  # (B,T,n_embd)
        x = self.net(x)  # (B,T,n_embd)
        logits = self.lm_head(x)  # (B,T,vocab_size)
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)
        return logits, loss

# %%
import numpy as np
import time

# %%
# 1. The RL Environment (Real Training)

class NanoGPTEnv:
    """
    Custom Environment that actually trains the TinyModel
    to calculate the reward (validation loss).
    """
    def __init__(self):
        # --- A. Data Loading (Do this once) ---
        try:
            with open('input.txt', 'r', encoding='utf-8') as f:
                text = f.read()
        except FileNotFoundError:
            # Fallback for testing if file missing
            text = "Hello world " * 1000
            print("Warning: input.txt not found, using dummy text.")

        self.chars = sorted(list(set(text)))
        self.vocab_size = len(self.chars)
        
        # Create mapping from characters to integers
        self.stoi = { ch:i for i,ch in enumerate(self.chars) }
        self.encode = lambda s: [self.stoi[c] for c in s]
        self.data = torch.tensor(self.encode(text), dtype=torch.long)
        
        # Split Data
        n = int(0.9 * len(self.data))
        self.train_data = self.data[:n]
        self.val_data = self.data[n:]
        
        # --- B. Define Search Space ---
        self.param_choices = {
            0: [1e-4, 5e-4, 1e-3, 5e-3, 1e-2],     # lr
            1: [16, 32, 64],                       # batch_size (reduced 128 for speed)
            2: [2, 4, 6],                          # n_layer
            3: [32, 64, 128],                      # n_embd
            4: [0.0, 0.1, 0.2],                    # dropout
        }
        self.param_names = ['lr', 'batch_size', 'n_layer', 'n_embd', 'dropout']
        
        self.state = 0
        self.current_config = {}
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
        # Hardcoded constants for TinyModel (not optimized)
        self.block_size = 64 # Matches your model's embedding(64)
        self.n_heads = 4     # Fixed head count
        self.training_iters = 100 # Keep low for RL speed (Proxy task)

    def get_batch(self, split, batch_size):
        """Helper to get a batch of data"""
        data = self.train_data if split == 'train' else self.val_data
        ix = torch.randint(len(data) - self.block_size, (batch_size,))
        x = torch.stack([data[i:i+self.block_size] for i in ix])
        y = torch.stack([data[i+1:i+self.block_size+1] for i in ix])
        return x.to(self.device), y.to(self.device)

    def reset(self):
        self.state = 0
        self.current_config = {}
        return self.state

    def step(self, action_index):
        param_name = self.param_names[self.state]
        
        # Safety check
        if action_index >= len(self.param_choices[self.state]):
             # Fallback if Q-table suggests invalid index
             action_index = 0
             
        selected_value = self.param_choices[self.state][action_index]
        self.current_config[param_name] = selected_value
        self.state += 1
        
        terminated = False
        reward = 0
        
        # If we have selected all hyperparameters, TRAIN!
        if self.state >= len(self.param_names):
            terminated = True
            val_loss = self._train_and_evaluate(self.current_config)
            
            # Reward = Inverse of Loss (Lower loss -> Higher Reward)
            # We square it to punish high loss more severely
            reward = 10.0 / (val_loss + 1e-6)
            
        return self.state, reward, terminated, self.current_config

    def _train_and_evaluate(self, config):
        """
        The 'Black Box' function.
        Instantiates the model with config, trains it, returns loss.
        """
        print(f"   -> Training: {config}", end=" ... ")
        
        try:
            # 1. Instantiate Model
            model = TinyModel(
                vocab_size=self.vocab_size,
                n_embd=config['n_embd'],
                n_heads=self.n_heads,
                n_layers=config['n_layer'],
                dropout=config['dropout']
            )
            model = model.to(self.device)
            
            # 2. Create Optimizer
            optimizer = torch.optim.AdamW(model.parameters(), lr=config['lr'])
            
            # 3. Short Training Loop (Proxy Task)
            model.train()
            for i in range(self.training_iters):
                xb, yb = self.get_batch('train', config['batch_size'])
                logits, loss = model(xb, yb)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                optimizer.step()
                
            # 4. Evaluation
            model.eval()
            with torch.no_grad():
                # Estimate loss on validation set (average of 10 batches)
                losses = torch.zeros(10)
                for k in range(10):
                    X, Y = self.get_batch('val', config['batch_size'])
                    logits, loss = model(X, Y)
                    losses[k] = loss.item()
                out_loss = losses.mean().item()
            
            print(f"Loss: {out_loss:.4f}")
            return out_loss
            
        except Exception as e:
            print(f"Training Failed: {e}")
            return 10.0 # High penalty for crash

# %%
class QLearningAgent:
    def __init__(self, env, alpha=0.1, gamma=0.9, epsilon=1.0, epsilon_decay=0.95, min_epsilon=0.1):
        self.env = env
        self.alpha = alpha        # Learning Rate
        self.gamma = gamma        # Discount Factor
        self.epsilon = epsilon    # Exploration Rate
        self.epsilon_decay = epsilon_decay
        self.min_epsilon = min_epsilon
        
        max_choices = max(len(opts) for opts in env.param_choices.values())
        num_states = len(env.param_names) + 1 
        self.q_table = np.zeros((num_states, max_choices))

    def choose_action(self, state):
        possible_actions = len(self.env.param_choices[state])
        if np.random.rand() < self.epsilon:
            return np.random.randint(possible_actions)
        else:
            return np.argmax(self.q_table[state, :possible_actions])

    def train(self, episodes):
        rewards_history = []
        best_loss = float('inf')
        best_config = None

        for episode in range(episodes):
            print(f"\n--- Episode {episode+1}/{episodes} (Epsilon: {self.epsilon:.2f}) ---")
            state = self.env.reset()
            total_reward = 0
            terminated = False
            trajectory = []

            while not terminated:
                action = self.choose_action(state)
                next_state, reward, terminated, info = self.env.step(action)
                trajectory.append((state, action, next_state))
                state = next_state
                
                # If terminated, 'reward' contains the result based on val_loss
                if terminated:
                    # Calculate actual loss back from reward for logging
                    # Reward was 10 / loss -> Loss = 10 / reward
                    actual_loss = 10.0 / (reward + 1e-6)
                    
                    if actual_loss < best_loss:
                        best_loss = actual_loss
                        best_config = info.copy()
                        print(f"   >>> NEW BEST FOUND! Loss: {best_loss:.4f}")

                    final_reward = reward

            # Backpropagate Reward
            for (s, a, s_next) in reversed(trajectory):
                # Simple Q-Update for Delayed Reward
                # Since intermediate rewards are 0, we just push the final value back
                best_next_q = np.max(self.q_table[s_next]) if s_next < len(self.env.param_choices) else 0
                
                # The immediate reward is 0 unless we are at the end
                current_r = final_reward if s_next == len(self.env.param_names) else 0
                
                self.q_table[s, a] += self.alpha * (current_r + self.gamma * best_next_q - self.q_table[s, a])

            self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)
            rewards_history.append(final_reward)

        return best_config, best_loss, rewards_history

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    print(f"Initializing RL Optimization on device: {'cuda' if torch.cuda.is_available() else 'cpu'}")
    
    # 1. Create Environment
    env = NanoGPTEnv()
    
    # 2. Create Agent
    agent = QLearningAgent(env)
    
    # ---------------------------------------------------------
    # CONFIGURATION FOR FINAL RUN
    # Your teammate ran 200 generations. Let's try 200 episodes.
    # ---------------------------------------------------------
    N_EPISODES = 200
    
    start_time = time.time()
    best_config, best_loss, rewards_history = agent.train(episodes=N_EPISODES)
    total_time = time.time() - start_time
    
    print("\n" + "="*40)
    print(f"Optimization Finished in {total_time:.2f}s")
    print(f"Best Loss Achieved: {best_loss:.4f}")
    print(f"Best Hyperparameters: {best_config}")
    print("="*40)

    # --- DATA VISUALIZATION FOR REPORT ---
    
    # Convert Rewards back to Loss for the graph (Loss = 10 / Reward)
    # Note: We add 1e-6 to avoid division by zero errors if reward is 0
    loss_history = [10.0 / (r + 1e-6) for r in rewards_history]

    # Calculate "Best So Far" for the curve (to make it monotonic like your teammate's)
    best_so_far = []
    current_best = float('inf')
    for loss in loss_history:
        if loss < current_best:
            current_best = loss
        best_so_far.append(current_best)

    # Create the Plot
    plt.figure(figsize=(10, 6))
    
    # Plot 1: Raw Loss per Episode (Noisy, shows exploration)
    plt.plot(loss_history, label='Episode Loss (Exploration)', color='lightblue', alpha=0.6)
    
    # Plot 2: Best Loss So Far (Monotonic, shows convergence)
    plt.plot(best_so_far, label='RL Best So Far (Converged)', color='blue', linewidth=2)

    plt.title(f'RL Optimization: Q-Learning vs Episodes\n(Best Loss: {best_loss:.4f})')
    plt.xlabel('Episodes')
    plt.ylabel('Validation Loss (Lower is Better)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Save the plot for your report
    plt.savefig('rl_optimization_results_1.png')
    print("Graph saved as 'rl_optimization_results.png'")
    plt.show()
# Out:
# Initializing RL Optimization on device: cpu
#
# --- Episode 1/200 (Epsilon: 1.00) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 4.0502
#    >>> NEW BEST FOUND! Loss: 4.0502
#
# --- Episode 2/200 (Epsilon: 0.95) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 3.2938
#    >>> NEW BEST FOUND! Loss: 3.2938
#
# --- Episode 3/200 (Epsilon: 0.90) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.3016
#
# --- Episode 4/200 (Epsilon: 0.86) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5305
#    >>> NEW BEST FOUND! Loss: 2.5305
#
# --- Episode 5/200 (Epsilon: 0.81) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.1} ... Loss: 2.5698
#
# --- Episode 6/200 (Epsilon: 0.77) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5822
#
# --- Episode 7/200 (Epsilon: 0.74) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.3155
#
# --- Episode 8/200 (Epsilon: 0.70) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.2} ... Loss: 4.0658
#
# --- Episode 9/200 (Epsilon: 0.66) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1285
#
# --- Episode 10/200 (Epsilon: 0.63) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.1} ... Loss: 2.8348
#
# --- Episode 11/200 (Epsilon: 0.60) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1101
#
# --- Episode 12/200 (Epsilon: 0.57) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.7879
#
# --- Episode 13/200 (Epsilon: 0.54) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.2821
#
# --- Episode 14/200 (Epsilon: 0.51) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5843
#
# --- Episode 15/200 (Epsilon: 0.49) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5994
#
# --- Episode 16/200 (Epsilon: 0.46) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.0160
#
# --- Episode 17/200 (Epsilon: 0.44) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.0665
#
# --- Episode 18/200 (Epsilon: 0.42) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0791
#
# --- Episode 19/200 (Epsilon: 0.40) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.2873
#
# --- Episode 20/200 (Epsilon: 0.38) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0904
#
# --- Episode 21/200 (Epsilon: 0.36) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1095
#
# --- Episode 22/200 (Epsilon: 0.34) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0770
#
# --- Episode 23/200 (Epsilon: 0.32) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.2872
#
# --- Episode 24/200 (Epsilon: 0.31) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0374
#
# --- Episode 25/200 (Epsilon: 0.29) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0741
#
# --- Episode 26/200 (Epsilon: 0.28) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 4.0333
#
# --- Episode 27/200 (Epsilon: 0.26) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1134
#
# --- Episode 28/200 (Epsilon: 0.25) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.7569
#
# --- Episode 29/200 (Epsilon: 0.24) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.8027
#
# --- Episode 30/200 (Epsilon: 0.23) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5943
#
# --- Episode 31/200 (Epsilon: 0.21) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.7800
#
# --- Episode 32/200 (Epsilon: 0.20) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0658
#
# --- Episode 33/200 (Epsilon: 0.19) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0517
#
# --- Episode 34/200 (Epsilon: 0.18) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.6161
#
# --- Episode 35/200 (Epsilon: 0.17) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0547
#
# --- Episode 36/200 (Epsilon: 0.17) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1071
#
# --- Episode 37/200 (Epsilon: 0.16) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5835
#
# --- Episode 38/200 (Epsilon: 0.15) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0817
#
# --- Episode 39/200 (Epsilon: 0.14) ---
#    -> Training: {'lr': 0.005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.6242
#
# --- Episode 40/200 (Epsilon: 0.14) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.2895
#
# --- Episode 41/200 (Epsilon: 0.13) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0312
#
# --- Episode 42/200 (Epsilon: 0.12) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1064
#
# --- Episode 43/200 (Epsilon: 0.12) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0294
#
# --- Episode 44/200 (Epsilon: 0.11) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0482
#
# --- Episode 45/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0643
#
# --- Episode 46/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0826
#
# --- Episode 47/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5829
#
# --- Episode 48/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.3075
#
# --- Episode 49/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0907
#
# --- Episode 50/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0622
#
# --- Episode 51/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1003
#
# --- Episode 52/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.9970
#
# --- Episode 53/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0967
#
# --- Episode 54/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0112
#
# --- Episode 55/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0582
#
# --- Episode 56/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0568
#
# --- Episode 57/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0662
#
# --- Episode 58/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.7801
#
# --- Episode 59/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0608
#
# --- Episode 60/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0881
#
# --- Episode 61/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0470
#
# --- Episode 62/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5615
#
# --- Episode 63/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5615
#
# --- Episode 64/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5576
#
# --- Episode 65/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.0608
#
# --- Episode 66/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0925
#
# --- Episode 67/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0544
#
# --- Episode 68/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0152
#
# --- Episode 69/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0376
#
# --- Episode 70/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5956
#
# --- Episode 71/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0639
#
# --- Episode 72/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.6148
#
# --- Episode 73/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0606
#
# --- Episode 74/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1111
#
# --- Episode 75/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0669
#
# --- Episode 76/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0765
#
# --- Episode 77/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0685
#
# --- Episode 78/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0676
#
# --- Episode 79/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0651
#
# --- Episode 80/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0448
#
# --- Episode 81/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0721
#
# --- Episode 82/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0745
#
# --- Episode 83/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0508
#
# --- Episode 84/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0373
#
# --- Episode 85/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0935
#
# --- Episode 86/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0935
#
# --- Episode 87/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0655
#
# --- Episode 88/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0659
#
# --- Episode 89/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0941
#
# --- Episode 90/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0132
#
# --- Episode 91/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.3050
#
# --- Episode 92/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0511
#
# --- Episode 93/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1043
#
# --- Episode 94/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0243
#
# --- Episode 95/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0641
#
# --- Episode 96/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.0752
#
# --- Episode 97/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1001
#
# --- Episode 98/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0742
#
# --- Episode 99/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0440
#
# --- Episode 100/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0670
#
# --- Episode 101/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0727
#
# --- Episode 102/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0567
#
# --- Episode 103/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0910
#
# --- Episode 104/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0524
#
# --- Episode 105/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0717
#
# --- Episode 106/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1163
#
# --- Episode 107/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 4.0470
#
# --- Episode 108/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0342
#
# --- Episode 109/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5535
#
# --- Episode 110/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0675
#
# --- Episode 111/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0886
#
# --- Episode 112/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0314
#
# --- Episode 113/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0692
#
# --- Episode 114/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0915
#
# --- Episode 115/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.1249
#
# --- Episode 116/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0850
#
# --- Episode 117/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0520
#
# --- Episode 118/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.6291
#
# --- Episode 119/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0815
#
# --- Episode 120/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0593
#
# --- Episode 121/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.2894
#
# --- Episode 122/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.7961
#
# --- Episode 123/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0599
#
# --- Episode 124/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0323
#
# --- Episode 125/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0647
#
# --- Episode 126/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1040
#
# --- Episode 127/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0675
#
# --- Episode 128/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 4.0585
#
# --- Episode 129/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0754
#
# --- Episode 130/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0885
#
# --- Episode 131/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0507
#
# --- Episode 132/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0904
#
# --- Episode 133/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5514
#
# --- Episode 134/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0623
#
# --- Episode 135/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0513
#
# --- Episode 136/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0480
#
# --- Episode 137/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5838
#
# --- Episode 138/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0940
#
# --- Episode 139/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0529
#
# --- Episode 140/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0765
#
# --- Episode 141/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0386
#
# --- Episode 142/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0643
#
# --- Episode 143/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.6260
#
# --- Episode 144/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0802
#
# --- Episode 145/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0474
#
# --- Episode 146/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0880
#
# --- Episode 147/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1046
#
# --- Episode 148/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0857
#
# --- Episode 149/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0500
#
# --- Episode 150/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0928
#
# --- Episode 151/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0528
#
# --- Episode 152/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.6016
#
# --- Episode 153/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0227
#
# --- Episode 154/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0481
#
# --- Episode 155/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.1069
#
# --- Episode 156/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0631
#
# --- Episode 157/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0497
#
# --- Episode 158/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0493
#
# --- Episode 159/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 4.0032
#
# --- Episode 160/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0249
#
# --- Episode 161/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0712
#
# --- Episode 162/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5693
#
# --- Episode 163/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1081
#
# --- Episode 164/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.2659
#
# --- Episode 165/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.0397
#
# --- Episode 166/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1019
#
# --- Episode 167/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.0471
#
# --- Episode 168/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1094
#
# --- Episode 169/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0552
#
# --- Episode 170/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1026
#
# --- Episode 171/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0752
#
# --- Episode 172/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0727
#
# --- Episode 173/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0932
#
# --- Episode 174/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0427
#
# --- Episode 175/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0247
#
# --- Episode 176/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0434
#
# --- Episode 177/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0376
#
# --- Episode 178/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0336
#
# --- Episode 179/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0770
#
# --- Episode 180/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0464
#
# --- Episode 181/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1059
#
# --- Episode 182/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0739
#
# --- Episode 183/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0035
#
# --- Episode 184/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0768
#
# --- Episode 185/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0739
#
# --- Episode 186/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.2865
#
# --- Episode 187/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0649
#
# --- Episode 188/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0506
#
# --- Episode 189/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0164
#
# --- Episode 190/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.6630
#
# --- Episode 191/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0817
#
# --- Episode 192/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0496
#
# --- Episode 193/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0705
#
# --- Episode 194/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.1239
#
# --- Episode 195/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5778
#
# --- Episode 196/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0735
#
# --- Episode 197/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0745
#
# --- Episode 198/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0329
#
# --- Episode 199/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0942
#
# --- Episode 200/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0578
#
# ========================================
# Optimization Finished in 137.64s
# Best Loss Achieved: 2.5305
# Best Hyperparameters: {'lr': 0.01, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0}
# ========================================
# Graph saved as 'rl_optimization_results.png'

# %% [markdown]
# 44sec of running for a loss of 2.52

# %%
class NanoGPTEnv:
    def __init__(self):
        # --- A. Data Loading ---
        try:
            with open('input.txt', 'r', encoding='utf-8') as f:
                text = f.read()
        except FileNotFoundError:
            text = "Hello world " * 1000
            print("Warning: input.txt not found.")

        self.chars = sorted(list(set(text)))
        self.vocab_size = len(self.chars)
        self.stoi = { ch:i for i,ch in enumerate(self.chars) }
        self.encode = lambda s: [self.stoi[c] for c in s]
        self.data = torch.tensor(self.encode(text), dtype=torch.long)
        
        n = int(0.9 * len(self.data))
        self.train_data = self.data[:n]
        self.val_data = self.data[n:]
        
        # --- B. Define Search Space ---
        self.param_choices = {
            0: [1e-4, 5e-4, 1e-3, 5e-3, 1e-2],     # lr
            1: [16, 32, 64],                       # batch_size
            2: [2, 4, 6],                          # n_layer
            3: [32, 64, 128],                      # n_embd
            4: [0.0, 0.1, 0.2],                    # dropout
        }
        self.param_names = ['lr', 'batch_size', 'n_layer', 'n_embd', 'dropout']
        
        self.state = 0
        self.current_config = {}
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.block_size = 64 
        self.n_heads = 4     
        self.training_iters = 200 

    def get_batch(self, split, batch_size):
        data = self.train_data if split == 'train' else self.val_data
        ix = torch.randint(len(data) - self.block_size, (batch_size,))
        x = torch.stack([data[i:i+self.block_size] for i in ix])
        y = torch.stack([data[i+1:i+self.block_size+1] for i in ix])
        return x.to(self.device), y.to(self.device)

    def reset(self):
        self.state = 0
        self.current_config = {}
        return self.state

    def step(self, action_index):
        param_name = self.param_names[self.state]
        
        if action_index >= len(self.param_choices[self.state]):
             action_index = 0
             
        selected_value = self.param_choices[self.state][action_index]
        self.current_config[param_name] = selected_value
        
        # *** REWARD SHAPING UPDATE ***
        # We apply a tiny negative reward (penalty) immediately for expensive choices.
        # This acts as a "soft" guidance before the final training.
        step_penalty = 0
        if param_name == 'n_layer':
            # Penalize deeper networks slightly (0.01 per layer)
            step_penalty = selected_value * 0.01 
        elif param_name == 'n_embd':
            # Penalize wider networks slightly (0.001 per embedding unit)
            step_penalty = selected_value * 0.001

        self.state += 1
        terminated = False
        
        # Intermediate reward is just the negative cost (to discourage waste)
        reward = -step_penalty
        
        if self.state >= len(self.param_names):
            terminated = True
            # Run training and measure time
            start_train = time.time()
            val_loss = self._train_and_evaluate(self.current_config)
            train_time = time.time() - start_train
            
            # *** NEW REWARD FUNCTION ***
            # Base Reward: Accuracy (10/Loss)
            accuracy_reward = 10.0 / (val_loss + 1e-6)
            
            # Penalty: Time (0.1 point penalty per second of training)
            time_penalty = train_time * 0.1
            
            # Total Reward
            reward = accuracy_reward - time_penalty
            
        return self.state, reward, terminated, self.current_config

    def _train_and_evaluate(self, config):
        # ... (Keep this function exactly the same as before) ...
        # For brevity, I assume you keep the existing training logic here.
        print(f"   -> Training: {config}", end=" ... ")
        try:
            model = TinyModel(self.vocab_size, config['n_embd'], self.n_heads, config['n_layer'], config['dropout']).to(self.device)
            optimizer = torch.optim.AdamW(model.parameters(), lr=config['lr'])
            model.train()
            for _ in range(self.training_iters):
                xb, yb = self.get_batch('train', config['batch_size'])
                logits, loss = model(xb, yb)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                optimizer.step()
            model.eval()
            with torch.no_grad():
                losses = torch.zeros(10)
                for k in range(10):
                    X, Y = self.get_batch('val', config['batch_size'])
                    _, loss = model(X, Y)
                    losses[k] = loss.item()
                out_loss = losses.mean().item()
            print(f"Loss: {out_loss:.4f}")
            return out_loss
        except Exception as e:
            print(f"Training Failed: {e}")
            return 10.0

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    print(f"Initializing RL Optimization on device: {'cuda' if torch.cuda.is_available() else 'cpu'}")
    
    # 1. Create Environment
    env = NanoGPTEnv()
    
    # 2. Create Agent
    agent = QLearningAgent(env)
    
    # ---------------------------------------------------------
    # CONFIGURATION FOR FINAL RUN
    # Your teammate ran 200 generations. Let's try 200 episodes.
    # ---------------------------------------------------------
    N_EPISODES = 200 
    
    start_time = time.time()
    best_config, best_loss, rewards_history = agent.train(episodes=N_EPISODES)
    total_time = time.time() - start_time
    
    print("\n" + "="*40)
    print(f"Optimization Finished in {total_time:.2f}s")
    print(f"Best Loss Achieved: {best_loss:.4f}")
    print(f"Best Hyperparameters: {best_config}")
    print("="*40)

    # --- DATA VISUALIZATION FOR REPORT ---
    
    # Convert Rewards back to Loss for the graph (Loss = 10 / Reward)
    # Note: We add 1e-6 to avoid division by zero errors if reward is 0
    loss_history = [10.0 / (r + 1e-6) for r in rewards_history]

    # Calculate "Best So Far" for the curve (to make it monotonic like your teammate's)
    best_so_far = []
    current_best = float('inf')
    for loss in loss_history:
        if loss < current_best:
            current_best = loss
        best_so_far.append(current_best)

    # Create the Plot
    plt.figure(figsize=(10, 6))
    
    # Plot 1: Raw Loss per Episode (Noisy, shows exploration)
    plt.plot(loss_history, label='Episode Loss (Exploration)', color='lightblue', alpha=0.6)
    
    # Plot 2: Best Loss So Far (Monotonic, shows convergence)
    plt.plot(best_so_far, label='RL Best So Far (Converged)', color='blue', linewidth=2)

    plt.title(f'RL Optimization: Q-Learning vs Episodes\n(Best Loss: {best_loss:.4f})')
    plt.xlabel('Episodes')
    plt.ylabel('Validation Loss (Lower is Better)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Save the plot for your report
    plt.savefig('rl_optimization_results_2.png')
    print("Graph saved as 'rl_optimization_results.png'")
    plt.show()
# Out:
# Initializing RL Optimization on device: cpu
#
# --- Episode 1/200 (Epsilon: 1.00) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 32, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5806
#    >>> NEW BEST FOUND! Loss: 2.6656
#
# --- Episode 2/200 (Epsilon: 0.95) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.7333
#
# --- Episode 3/200 (Epsilon: 0.90) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3433
#
# --- Episode 4/200 (Epsilon: 0.86) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 2.9923
#
# --- Episode 5/200 (Epsilon: 0.81) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5180
#    >>> NEW BEST FOUND! Loss: 2.6147
#
# --- Episode 6/200 (Epsilon: 0.77) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.6423
#
# --- Episode 7/200 (Epsilon: 0.74) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.8286
#
# --- Episode 8/200 (Epsilon: 0.70) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4230
#
# --- Episode 9/200 (Epsilon: 0.66) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 2.5586
#
# --- Episode 10/200 (Epsilon: 0.63) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8473
#
# --- Episode 11/200 (Epsilon: 0.60) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3627
#
# --- Episode 12/200 (Epsilon: 0.57) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.7988
#
# --- Episode 13/200 (Epsilon: 0.54) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3344
#
# --- Episode 14/200 (Epsilon: 0.51) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3657
#
# --- Episode 15/200 (Epsilon: 0.49) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0637
#
# --- Episode 16/200 (Epsilon: 0.46) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 3.4350
#
# --- Episode 17/200 (Epsilon: 0.44) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.9764
#
# --- Episode 18/200 (Epsilon: 0.42) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.7969
#
# --- Episode 19/200 (Epsilon: 0.40) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 3.3446
#
# --- Episode 20/200 (Epsilon: 0.38) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5249
#    >>> NEW BEST FOUND! Loss: 2.5607
#
# --- Episode 21/200 (Epsilon: 0.36) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3630
#
# --- Episode 22/200 (Epsilon: 0.34) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3601
#
# --- Episode 23/200 (Epsilon: 0.32) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4173
#
# --- Episode 24/200 (Epsilon: 0.31) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8092
#
# --- Episode 25/200 (Epsilon: 0.29) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7989
#
# --- Episode 26/200 (Epsilon: 0.28) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3712
#
# --- Episode 27/200 (Epsilon: 0.26) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0590
#
# --- Episode 28/200 (Epsilon: 0.25) ---
#    -> Training: {'lr': 0.005, 'batch_size': 32, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5482
#
# --- Episode 29/200 (Epsilon: 0.24) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 3.3691
#
# --- Episode 30/200 (Epsilon: 0.23) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3606
#
# --- Episode 31/200 (Epsilon: 0.21) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3576
#
# --- Episode 32/200 (Epsilon: 0.20) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3566
#
# --- Episode 33/200 (Epsilon: 0.19) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3600
#
# --- Episode 34/200 (Epsilon: 0.18) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0768
#
# --- Episode 35/200 (Epsilon: 0.17) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.8175
#
# --- Episode 36/200 (Epsilon: 0.17) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4019
#
# --- Episode 37/200 (Epsilon: 0.16) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3949
#
# --- Episode 38/200 (Epsilon: 0.15) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3388
#
# --- Episode 39/200 (Epsilon: 0.14) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4151
#
# --- Episode 40/200 (Epsilon: 0.14) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0594
#
# --- Episode 41/200 (Epsilon: 0.13) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3755
#
# --- Episode 42/200 (Epsilon: 0.12) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3660
#
# --- Episode 43/200 (Epsilon: 0.12) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3533
#
# --- Episode 44/200 (Epsilon: 0.11) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3452
#
# --- Episode 45/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3537
#
# --- Episode 46/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 32, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5253
#
# --- Episode 47/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4184
#
# --- Episode 48/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3555
#
# --- Episode 49/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3943
#
# --- Episode 50/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0753
#
# --- Episode 51/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.6150
#
# --- Episode 52/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3932
#
# --- Episode 53/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3777
#
# --- Episode 54/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7818
#
# --- Episode 55/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3215
#
# --- Episode 56/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5203
#    >>> NEW BEST FOUND! Loss: 2.5529
#
# --- Episode 57/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3833
#
# --- Episode 58/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3696
#
# --- Episode 59/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3608
#
# --- Episode 60/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4053
#
# --- Episode 61/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4052
#
# --- Episode 62/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5569
#
# --- Episode 63/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5481
#
# --- Episode 64/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3305
#
# --- Episode 65/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5592
#
# --- Episode 66/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4223
#
# --- Episode 67/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3522
#
# --- Episode 68/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3786
#
# --- Episode 69/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3881
#
# --- Episode 70/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3746
#
# --- Episode 71/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3199
#
# --- Episode 72/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3620
#
# --- Episode 73/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3976
#
# --- Episode 74/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3872
#
# --- Episode 75/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3576
#
# --- Episode 76/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3823
#
# --- Episode 77/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3615
#
# --- Episode 78/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3843
#
# --- Episode 79/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4238
#
# --- Episode 80/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3243
#
# --- Episode 81/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3801
#
# --- Episode 82/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3890
#
# --- Episode 83/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3542
#
# --- Episode 84/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4114
#
# --- Episode 85/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5030
#
# --- Episode 86/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4131
#
# --- Episode 87/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3802
#
# --- Episode 88/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3130
#
# --- Episode 89/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4216
#
# --- Episode 90/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3624
#
# --- Episode 91/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3294
#
# --- Episode 92/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8077
#
# --- Episode 93/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5314
#
# --- Episode 94/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3486
#
# --- Episode 95/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3035
#
# --- Episode 96/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4160
#
# --- Episode 97/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3340
#
# --- Episode 98/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4426
#
# --- Episode 99/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3751
#
# --- Episode 100/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3646
#
# --- Episode 101/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7841
#
# --- Episode 102/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4105
#
# --- Episode 103/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4269
#
# --- Episode 104/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3767
#
# --- Episode 105/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5564
#
# --- Episode 106/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4304
#
# --- Episode 107/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.6748
#
# --- Episode 108/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3346
#
# --- Episode 109/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4117
#
# --- Episode 110/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3600
#
# --- Episode 111/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4205
#
# --- Episode 112/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3834
#
# --- Episode 113/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3321
#
# --- Episode 114/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5457
#
# --- Episode 115/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.6051
#
# --- Episode 116/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3546
#
# --- Episode 117/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3318
#
# --- Episode 118/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0327
#
# --- Episode 119/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3053
#
# --- Episode 120/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8065
#
# --- Episode 121/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3326
#
# --- Episode 122/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3992
#
# --- Episode 123/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3702
#
# --- Episode 124/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3238
#
# --- Episode 125/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3304
#
# --- Episode 126/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3710
#
# --- Episode 127/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3860
#
# --- Episode 128/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3580
#
# --- Episode 129/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.2906
#
# --- Episode 130/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3444
#
# --- Episode 131/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3742
#
# --- Episode 132/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5846
#
# --- Episode 133/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3735
#
# --- Episode 134/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3980
#
# --- Episode 135/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3799
#
# --- Episode 136/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3443
#
# --- Episode 137/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3356
#
# --- Episode 138/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3762
#
# --- Episode 139/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4131
#
# --- Episode 140/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3378
#
# --- Episode 141/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3601
#
# --- Episode 142/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3743
#
# --- Episode 143/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3690
#
# --- Episode 144/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 3.3388
#
# --- Episode 145/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5226
#
# --- Episode 146/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3772
#
# --- Episode 147/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3868
#
# --- Episode 148/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4042
#
# --- Episode 149/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3672
#
# --- Episode 150/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3526
#
# --- Episode 151/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3968
#
# --- Episode 152/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3383
#
# --- Episode 153/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4170
#
# --- Episode 154/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3813
#
# --- Episode 155/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3956
#
# --- Episode 156/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3907
#
# --- Episode 157/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.8161
#
# --- Episode 158/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3412
#
# --- Episode 159/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4223
#
# --- Episode 160/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3615
#
# --- Episode 161/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3359
#
# --- Episode 162/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3505
#
# --- Episode 163/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3357
#
# --- Episode 164/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 3.4119
#
# --- Episode 165/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3597
#
# --- Episode 166/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3603
#
# --- Episode 167/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3867
#
# --- Episode 168/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3855
#
# --- Episode 169/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3688
#
# --- Episode 170/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4124
#
# --- Episode 171/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3574
#
# --- Episode 172/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3863
#
# --- Episode 173/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3486
#
# --- Episode 174/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3947
#
# --- Episode 175/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5564
#
# --- Episode 176/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4286
#
# --- Episode 177/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.6479
#
# --- Episode 178/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4145
#
# --- Episode 179/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4509
#
# --- Episode 180/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3801
#
# --- Episode 181/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.8294
#
# --- Episode 182/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3527
#
# --- Episode 183/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3630
#
# --- Episode 184/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3546
#
# --- Episode 185/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 3.3691
#
# --- Episode 186/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3340
#
# --- Episode 187/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3971
#
# --- Episode 188/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3686
#
# --- Episode 189/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4140
#
# --- Episode 190/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4109
#
# --- Episode 191/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3955
#
# --- Episode 192/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3178
#
# --- Episode 193/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3970
#
# --- Episode 194/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3494
#
# --- Episode 195/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4045
#
# --- Episode 196/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4453
#
# --- Episode 197/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.1} ... Loss: 3.3217
#
# --- Episode 198/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3814
#
# --- Episode 199/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0709
#
# --- Episode 200/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.3861
#
# ========================================
# Optimization Finished in 141.36s
# Best Loss Achieved: 2.5529
# Best Hyperparameters: {'lr': 0.01, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0}
# ========================================
# Graph saved as 'rl_optimization_results.png'

# %% [markdown]
# 1m10 of running for a loss of 2.57

# %%
import torch.optim as optim

# %%
# ==========================================
# 2. The Deep Q-Network (DQN) Agent
# ==========================================

class QNetwork(nn.Module):
    """A simple Neural Network to approximate Q-Values"""
    def __init__(self, state_dim, action_dim):
        super().__init__()
        # Input: State (One-Hot Encoded) -> Hidden Layer -> Output: Q-Values for all actions
        self.net = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim)
        )

    def forward(self, x):
        return self.net(x)

class DQNAgent:
    def __init__(self, env, alpha=0.001, gamma=0.9, epsilon=1.0, epsilon_decay=0.95, min_epsilon=0.1):
        self.env = env
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.min_epsilon = min_epsilon
        
        # Dimensions
        self.num_states = len(env.param_names) + 1
        # Find the max number of actions across all states to size the network output
        self.max_actions = max(len(opts) for opts in env.param_choices.values())
        
        # The Brain: A Neural Network instead of a Table
        # Input size = num_states (we will use One-Hot encoding for the state)
        self.policy_net = QNetwork(self.num_states, self.max_actions).to(env.device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=alpha)
        self.loss_fn = nn.MSELoss()

    def get_state_tensor(self, state_idx):
        """Converts integer state index to One-Hot Tensor (e.g., 3 -> [0,0,0,1,0...])"""
        x = np.zeros(self.num_states)
        x[state_idx] = 1.0
        return torch.FloatTensor(x).unsqueeze(0).to(self.env.device)

    def choose_action(self, state_idx):
        possible_actions = len(self.env.param_choices[state_idx])
        
        if np.random.rand() < self.epsilon:
            return np.random.randint(possible_actions)
        else:
            # Exploitation: Ask the Neural Network
            with torch.no_grad():
                state_tensor = self.get_state_tensor(state_idx)
                q_values = self.policy_net(state_tensor)
                # We only care about valid actions for this specific state
                valid_q_values = q_values[0, :possible_actions]
                return torch.argmax(valid_q_values).item()

    def train(self, episodes):
        rewards_history = []
        best_loss = float('inf')
        best_config = None

        for episode in range(episodes):
            print(f"\n--- Episode {episode+1}/{episodes} (Epsilon: {self.epsilon:.2f}) ---")
            state_idx = self.env.reset()
            terminated = False
            trajectory = []
            final_reward = 0

            # --- 1. Collect Experience (Run the Episode) ---
            while not terminated:
                action = self.choose_action(state_idx)
                next_state_idx, reward, terminated, info = self.env.step(action)
                trajectory.append((state_idx, action, next_state_idx))
                state_idx = next_state_idx
                
                if terminated:
                    # Logging logic (same as before)
                    actual_loss = 10.0 / (reward + 1e-6) # Approx inversion for display
                    # Note: With reward shaping, this inversion is less accurate for display, 
                    # but we use the returned 'info' config to verify.
                    
                    # We only update 'best' if we actually ran a training loop (reward != 0)
                    if reward != 0 and actual_loss < best_loss:
                        # We verify the loss isn't negative/weird due to shaping
                        if actual_loss > 0: 
                            best_loss = actual_loss
                            best_config = info.copy()
                            print(f"   >>> NEW BEST FOUND! (Approx Loss: {best_loss:.4f})")
                    
                    final_reward = reward

            # --- 2. Train the Neural Network (Backpropagation) ---
            # We train on the trajectory we just created
            
            # Target Q-Value (Bellman Equation for DQN)
            # Q(s,a) = r + gamma * max(Q(s', a'))
            
            for (s_idx, a, s_next_idx) in reversed(trajectory):
                state_tensor = self.get_state_tensor(s_idx)
                
                # Get current prediction
                q_values = self.policy_net(state_tensor)
                current_q = q_values[0, a]
                
                # Calculate Target
                with torch.no_grad():
                    if s_next_idx == len(self.env.param_names):
                        # Terminal state: Target is just the reward
                        target_q = torch.tensor(final_reward).to(self.env.device)
                    else:
                        # Non-terminal: Reward (0) + Gamma * Max Next Q
                        next_state_tensor = self.get_state_tensor(s_next_idx)
                        next_q_values = self.policy_net(next_state_tensor)
                        # Mask invalid actions for next state to ensure fair max
                        valid_next_actions = len(self.env.param_choices[s_next_idx])
                        max_next_q = torch.max(next_q_values[0, :valid_next_actions])
                        
                        # Intermediate reward is 0 (or penalty from shaping)
                        # In our env, env.step returns intermediate rewards (shaping penalties)
                        # But for simplicity in this trajectory loop, we use 0 for intermediate
                        # and push the final huge reward back.
                        # *Correction*: To use Reward Shaping properly with DQN, we should have stored 
                        # individual rewards in the trajectory. Let's simplify:
                        # We will propagate the FINAL reward back, decaying it.
                        
                        target_q = final_reward + (self.gamma * max_next_q)

                # Compute Loss
                loss = self.loss_fn(current_q, target_q)
                
                # Optimize
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

            # Decay Epsilon
            self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)
            rewards_history.append(final_reward)

        return best_config, best_loss, rewards_history

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    print(f"Initializing RL Optimization on device: {'cuda' if torch.cuda.is_available() else 'cpu'}")
    
    # 1. Create Environment
    env = NanoGPTEnv()
    
    # 2. Create Agent
    agent = DQNAgent(env) # Was QLearningAgent(env)    
    # ---------------------------------------------------------
    # CONFIGURATION FOR FINAL RUN
    # Your teammate ran 200 generations. Let's try 100-150 episodes.
    # ---------------------------------------------------------
    N_EPISODES = 200
    
    start_time = time.time()
    best_config, best_loss, rewards_history = agent.train(episodes=N_EPISODES)
    total_time = time.time() - start_time
    
    print("\n" + "="*40)
    print(f"Optimization Finished in {total_time:.2f}s")
    print(f"Best Loss Achieved: {best_loss:.4f}")
    print(f"Best Hyperparameters: {best_config}")
    print("="*40)

    # --- DATA VISUALIZATION FOR REPORT ---
    
    # Convert Rewards back to Loss for the graph (Loss = 10 / Reward)
    # Note: We add 1e-6 to avoid division by zero errors if reward is 0
    loss_history = [10.0 / (r + 1e-6) for r in rewards_history]

    # Calculate "Best So Far" for the curve (to make it monotonic like your teammate's)
    best_so_far = []
    current_best = float('inf')
    for loss in loss_history:
        if loss < current_best:
            current_best = loss
        best_so_far.append(current_best)

    # Create the Plot
    plt.figure(figsize=(10, 6))
    
    # Plot 1: Raw Loss per Episode (Noisy, shows exploration)
    plt.plot(loss_history, label='Episode Loss (Exploration)', color='lightblue', alpha=0.6)
    
    # Plot 2: Best Loss So Far (Monotonic, shows convergence)
    plt.plot(best_so_far, label='RL Best So Far (Converged)', color='blue', linewidth=2)

    plt.title(f'RL Optimization: Q-Learning vs Episodes\n(Best Loss: {best_loss:.4f})')
    plt.xlabel('Episodes')
    plt.ylabel('Validation Loss (Lower is Better)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Save the plot for your report
    plt.savefig('rl_optimization_results_3.png')
    print("Graph saved as 'rl_optimization_results.png'")
    plt.show()
# Out:
# Initializing RL Optimization on device: cpu
#
# --- Episode 1/200 (Epsilon: 1.00) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.5335
#    >>> NEW BEST FOUND! (Approx Loss: 2.5861)
#
# --- Episode 2/200 (Epsilon: 0.95) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.7785
#
# --- Episode 3/200 (Epsilon: 0.90) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.3811
#
# --- Episode 4/200 (Epsilon: 0.86) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0133
#
# --- Episode 5/200 (Epsilon: 0.81) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7582
#
# --- Episode 6/200 (Epsilon: 0.77) ---
#    -> Training: {'lr': 0.005, 'batch_size': 32, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5385
#
# --- Episode 7/200 (Epsilon: 0.74) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5929
#
# --- Episode 8/200 (Epsilon: 0.70) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.6257
#
# --- Episode 9/200 (Epsilon: 0.66) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5684
#
# --- Episode 10/200 (Epsilon: 0.63) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5360
#
# --- Episode 11/200 (Epsilon: 0.60) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.8365
#
# --- Episode 12/200 (Epsilon: 0.57) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.1} ... Loss: 2.8164
#
# --- Episode 13/200 (Epsilon: 0.54) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5530
#
# --- Episode 14/200 (Epsilon: 0.51) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.5364
#
# --- Episode 15/200 (Epsilon: 0.49) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8522
#
# --- Episode 16/200 (Epsilon: 0.46) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7791
#
# --- Episode 17/200 (Epsilon: 0.44) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8422
#
# --- Episode 18/200 (Epsilon: 0.42) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7992
#
# --- Episode 19/200 (Epsilon: 0.40) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.5476
#
# --- Episode 20/200 (Epsilon: 0.38) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.5196
#    >>> NEW BEST FOUND! (Approx Loss: 2.5664)
#
# --- Episode 21/200 (Epsilon: 0.36) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8932
#
# --- Episode 22/200 (Epsilon: 0.34) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8165
#
# --- Episode 23/200 (Epsilon: 0.32) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 3.0215
#
# --- Episode 24/200 (Epsilon: 0.31) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5707
#
# --- Episode 25/200 (Epsilon: 0.29) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8564
#
# --- Episode 26/200 (Epsilon: 0.28) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8572
#
# --- Episode 27/200 (Epsilon: 0.26) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.9350
#
# --- Episode 28/200 (Epsilon: 0.25) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7926
#
# --- Episode 29/200 (Epsilon: 0.24) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0416
#
# --- Episode 30/200 (Epsilon: 0.23) ---
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8346
#
# --- Episode 31/200 (Epsilon: 0.21) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0605
#
# --- Episode 32/200 (Epsilon: 0.20) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8968
#
# --- Episode 33/200 (Epsilon: 0.19) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8742
#
# --- Episode 34/200 (Epsilon: 0.18) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7765
#
# --- Episode 35/200 (Epsilon: 0.17) ---
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0559
#
# --- Episode 36/200 (Epsilon: 0.17) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5427
#
# --- Episode 37/200 (Epsilon: 0.16) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7907
#
# --- Episode 38/200 (Epsilon: 0.15) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8097
#
# --- Episode 39/200 (Epsilon: 0.14) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.5840
#
# --- Episode 40/200 (Epsilon: 0.14) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8104
#
# --- Episode 41/200 (Epsilon: 0.13) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7896
#
# --- Episode 42/200 (Epsilon: 0.12) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8332
#
# --- Episode 43/200 (Epsilon: 0.12) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7241
#
# --- Episode 44/200 (Epsilon: 0.11) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7412
#
# --- Episode 45/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7411
#
# --- Episode 46/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8575
#
# --- Episode 47/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8263
#
# --- Episode 48/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8387
#
# --- Episode 49/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.8208
#
# --- Episode 50/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8137
#
# --- Episode 51/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8632
#
# --- Episode 52/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.0} ... Loss: 3.4271
#
# --- Episode 53/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8322
#
# --- Episode 54/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8911
#
# --- Episode 55/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8683
#
# --- Episode 56/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7973
#
# --- Episode 57/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0412
#
# --- Episode 58/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8778
#
# --- Episode 59/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8603
#
# --- Episode 60/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.9327
#
# --- Episode 61/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8983
#
# --- Episode 62/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8858
#
# --- Episode 63/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7915
#
# --- Episode 64/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8610
#
# --- Episode 65/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.5918
#
# --- Episode 66/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8526
#
# --- Episode 67/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8053
#
# --- Episode 68/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7562
#
# --- Episode 69/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8770
#
# --- Episode 70/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7882
#
# --- Episode 71/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8156
#
# --- Episode 72/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.7754
#
# --- Episode 73/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.9103
#
# --- Episode 74/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8798
#
# --- Episode 75/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8468
#
# --- Episode 76/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.6485
#
# --- Episode 77/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7750
#
# --- Episode 78/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8333
#
# --- Episode 79/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8291
#
# --- Episode 80/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8181
#
# --- Episode 81/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.9155
#
# --- Episode 82/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8540
#
# --- Episode 83/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7364
#
# --- Episode 84/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8276
#
# --- Episode 85/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.8178
#
# --- Episode 86/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8468
#
# --- Episode 87/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7618
#
# --- Episode 88/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8784
#
# --- Episode 89/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8154
#
# --- Episode 90/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4261
#
# --- Episode 91/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7679
#
# --- Episode 92/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8107
#
# --- Episode 93/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8091
#
# --- Episode 94/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7994
#
# --- Episode 95/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8809
#
# --- Episode 96/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8165
#
# --- Episode 97/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.3849
#
# --- Episode 98/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8576
#
# --- Episode 99/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8751
#
# --- Episode 100/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8834
#
# --- Episode 101/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8208
#
# --- Episode 102/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.3839
#
# --- Episode 103/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.8772
#
# --- Episode 104/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.9064
#
# --- Episode 105/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8949
#
# --- Episode 106/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8301
#
# --- Episode 107/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8054
#
# --- Episode 108/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8337
#
# --- Episode 109/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0747
#
# --- Episode 110/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0558
#
# --- Episode 111/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8305
#
# --- Episode 112/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.9626
#
# --- Episode 113/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8235
#
# --- Episode 114/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.5847
#
# --- Episode 115/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8738
#
# --- Episode 116/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8324
#
# --- Episode 117/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8043
#
# --- Episode 118/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.8652
#
# --- Episode 119/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7890
#
# --- Episode 120/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7354
#
# --- Episode 121/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0456
#
# --- Episode 122/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0890
#
# --- Episode 123/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0100
#
# --- Episode 124/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0594
#
# --- Episode 125/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0664
#
# --- Episode 126/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7844
#
# --- Episode 127/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8773
#
# --- Episode 128/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8620
#
# --- Episode 129/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.1268
#
# --- Episode 130/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0562
#
# --- Episode 131/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0734
#
# --- Episode 132/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0573
#
# --- Episode 133/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0226
#
# --- Episode 134/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.9012
#
# --- Episode 135/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.8365
#
# --- Episode 136/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0019
#
# --- Episode 137/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0703
#
# --- Episode 138/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0872
#
# --- Episode 139/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 3.0926
#
# --- Episode 140/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0572
#
# --- Episode 141/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0785
#
# --- Episode 142/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0372
#
# --- Episode 143/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8566
#
# --- Episode 144/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0909
#
# --- Episode 145/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0869
#
# --- Episode 146/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0626
#
# --- Episode 147/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.1} ... Loss: 3.0542
#
# --- Episode 148/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0915
#
# --- Episode 149/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0673
#
# --- Episode 150/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0681
#
# --- Episode 151/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0138
#
# --- Episode 152/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0039
#
# --- Episode 153/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0716
#
# --- Episode 154/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0273
#
# --- Episode 155/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0624
#
# --- Episode 156/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.1124
#
# --- Episode 157/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0826
#
# --- Episode 158/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.0} ... Loss: 2.9998
#
# --- Episode 159/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0077
#
# --- Episode 160/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0978
#
# --- Episode 161/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0757
#
# --- Episode 162/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0598
#
# --- Episode 163/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0159
#
# --- Episode 164/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0370
#
# --- Episode 165/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0888
#
# --- Episode 166/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0736
#
# --- Episode 167/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0474
#
# --- Episode 168/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0455
#
# --- Episode 169/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5429
#
# --- Episode 170/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0798
#
# --- Episode 171/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.8278
#
# --- Episode 172/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0313
#
# --- Episode 173/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5889
#
# --- Episode 174/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0633
#
# --- Episode 175/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0899
#
# --- Episode 176/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0204
#
# --- Episode 177/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0554
#
# --- Episode 178/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0713
#
# --- Episode 179/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.0} ... Loss: 3.0183
#
# --- Episode 180/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0642
#
# --- Episode 181/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 3.0924
#
# --- Episode 182/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0493
#
# --- Episode 183/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0133
#
# --- Episode 184/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.1006
#
# --- Episode 185/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0810
#
# --- Episode 186/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.1046
#
# --- Episode 187/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.1086
#
# --- Episode 188/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0253
#
# --- Episode 189/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0559
#
# --- Episode 190/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0780
#
# --- Episode 191/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0533
#
# --- Episode 192/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0104
#
# --- Episode 193/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0632
#
# --- Episode 194/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.1128
#
# --- Episode 195/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0534
#
# --- Episode 196/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5695
#
# --- Episode 197/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0708
#
# --- Episode 198/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0454
#
# --- Episode 199/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 3.0567
#
# --- Episode 200/200 (Epsilon: 0.10) ---
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 3.0777
#
# ========================================
# Optimization Finished in 187.54s
# Best Loss Achieved: 2.5664
# Best Hyperparameters: {'lr': 0.005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2}
# ========================================
# Graph saved as 'rl_optimization_results.png'

# %% [markdown]
# 55sec of running for a loss of 2.57

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import time
import matplotlib.pyplot as plt
from torch.nn import functional as F

# ==========================================
# 1. DQN Agent (Serial / Single Process)
# ==========================================

# Q-Network Definition
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim)
        )
    def forward(self, x): return self.net(x)

class DQNAgent:
    def __init__(self, env, alpha=0.001, gamma=0.9, epsilon=1.0):
        self.env = env
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = 0.95
        self.min_epsilon = 0.1
        
        self.num_states = len(env.param_names) + 1
        self.max_actions = max(len(opts) for opts in env.param_choices.values())
        
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
        self.policy_net = QNetwork(self.num_states, self.max_actions).to(self.device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=alpha)
        self.loss_fn = nn.MSELoss()

    def get_state_tensor(self, state_idx):
        x = np.zeros(self.num_states)
        x[state_idx] = 1.0
        return torch.FloatTensor(x).unsqueeze(0).to(self.device)

    def choose_action(self, state_idx):
        possible_actions = len(self.env.param_choices[state_idx])
        if np.random.rand() < self.epsilon:
            return np.random.randint(possible_actions)
        else:
            with torch.no_grad():
                q = self.policy_net(self.get_state_tensor(state_idx))
                valid_q = q[0, :possible_actions]
                return torch.argmax(valid_q).item()

    def train(self, episodes=100):
        rewards_history = []
        best_loss = float('inf')
        best_config = None
        
        print(f"Starting Training: {episodes} episodes...")
        
        for episode in range(episodes):
            state_idx = self.env.reset()
            terminated = False
            trajectory = []
            
            # --- 1. Run Episode ---
            while not terminated:
                action = self.choose_action(state_idx)
                next_state_idx, reward, terminated, info = self.env.step(action)
                
                # *** CRITICAL: Explicit Memory Cleanup after the expensive training step ***
                if self.device == 'cuda':
                    torch.cuda.empty_cache()
                
                # Store transition
                trajectory.append((state_idx, action, reward, next_state_idx))
                state_idx = next_state_idx
                
                if terminated:
                    # Reverse engineer the loss from the reward for logging
                    if reward > 0:
                        approx_loss = 10.0 / (reward + 1e-6)
                        if approx_loss < best_loss:
                            best_loss = approx_loss
                            best_config = info
                            print(f"Episode {episode+1}: New Best! Loss ~ {best_loss:.4f} | Config: {best_config}")

                    final_reward = reward

            # --- 2. Update Network (Backpropagation) ---
            cumulative_reward = final_reward
            
            for (s_idx, a, r_step, s_next_idx) in reversed(trajectory):
                state_tensor = self.get_state_tensor(s_idx)
                pred_q = self.policy_net(state_tensor)[0, a]
                
                with torch.no_grad():
                    if s_next_idx == len(self.env.param_names):
                        target = torch.tensor(cumulative_reward).to(self.device)
                    else:
                        next_s = self.get_state_tensor(s_next_idx)
                        next_qs = self.policy_net(next_s)
                        valid_acts = len(self.env.param_choices[s_next_idx])
                        max_next_q = torch.max(next_qs[0, :valid_acts])
                        target = r_step + (self.gamma * max_next_q)

                loss = self.loss_fn(pred_q, target)
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
                
            rewards_history.append(final_reward)
            
            self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)
            
            if (episode+1) % 10 == 0:
                print(f"Episode {episode+1}/{episodes} complete. Epsilon: {self.epsilon:.2f}")

        return best_config, best_loss, rewards_history

# ==========================================
# 2. Main Execution
# ==========================================
if __name__ == "__main__":
    
    # Instantiate the Environment (fixes the NameError from before)
    try:
        env = NanoGPTEnv()
    except NameError:
        print("Error: NanoGPTEnv is not defined. Please ensure the cell defining NanoGPTEnv has been run.")
        # If the environment isn't defined, we can't proceed.
        exit()

    # Instantiate the Agent
    agent = DQNAgent(env)
    
    # Run Training
    start_time = time.time()
    best_config, best_loss, rewards = agent.train(episodes=100)
    total_time = time.time() - start_time
    
    print("\n" + "="*40)
    print(f"Optimization Finished in {total_time:.2f}s")
    print(f"Best Loss: {best_loss:.4f}")
    print(f"Best Config: {best_config}")
    print("="*40)
    
    # Visualization
    loss_history = [10.0 / (r + 1e-6) for r in rewards]
    best_so_far = np.minimum.accumulate(loss_history)

    plt.figure(figsize=(10, 6))
    plt.plot(loss_history, label='Episode Loss (Exploration)', color='lightblue', alpha=0.6)
    plt.plot(best_so_far, label='Best So Far (Exploitation)', color='blue', linewidth=2)
    plt.title(f'DQN Optimization Results\nBest Loss: {best_loss:.4f}')
    plt.xlabel('Episodes')
    plt.ylabel('Validation Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.savefig('dqn_optimization_results.png')
    plt.show()
# Out:
# Starting Training: 100 episodes...
#    -> Training: {'lr': 0.005, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5067
# Episode 1: New Best! Loss ~ 2.5571 | Config: {'lr': 0.005, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0}
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.1} ... Loss: 2.5383
#    -> Training: {'lr': 0.005, 'batch_size': 32, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5380
#    -> Training: {'lr': 0.0001, 'batch_size': 32, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0545
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.6216
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.8472
#    -> Training: {'lr': 0.005, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.5242
#    -> Training: {'lr': 0.0005, 'batch_size': 32, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0436
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.1327
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0902
# Episode 10/100 complete. Epsilon: 0.60
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 4, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8864
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.8192
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8451
#    -> Training: {'lr': 0.0005, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0513
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8836
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.2} ... Loss: 3.4226
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.1029
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 2.8621
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8740
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 2.5785
# Episode 20/100 complete. Epsilon: 0.36
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.5516
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.1064
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 64, 'dropout': 0.2} ... Loss: 2.6662
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8572
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8621
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 64, 'dropout': 0.0} ... Loss: 2.6450
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8531
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 2.8636
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.5674
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8852
# Episode 30/100 complete. Epsilon: 0.21
#    -> Training: {'lr': 0.001, 'batch_size': 32, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8706
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8776
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.7805
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.9092
#    -> Training: {'lr': 0.01, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5692
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.9114
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8573
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8751
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0633
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.9027
# Episode 40/100 complete. Epsilon: 0.13
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5581
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.7920
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 2.8512
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8340
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8254
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.9091
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8608
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8264
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8707
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8701
# Episode 50/100 complete. Epsilon: 0.10
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8887
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.1374
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 128, 'dropout': 0.2} ... Loss: 2.5182
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.9063
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8992
#    -> Training: {'lr': 0.001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8171
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8837
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8521
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8412
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7599
# Episode 60/100 complete. Epsilon: 0.10
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8101
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7909
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8199
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7587
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7839
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8294
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8765
#    -> Training: {'lr': 0.0001, 'batch_size': 64, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.1} ... Loss: 3.7348
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8427
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0888
# Episode 70/100 complete. Epsilon: 0.10
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.0521
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8557
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8600
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8384
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8755
#    -> Training: {'lr': 0.001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 2.8809
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7492
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7087
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7795
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8506
# Episode 80/100 complete. Epsilon: 0.10
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8275
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.9179
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8426
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8183
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8849
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.0} ... Loss: 3.8611
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.1133
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.9047
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8926
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8304
# Episode 90/100 complete. Epsilon: 0.10
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8805
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8575
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0875
#    -> Training: {'lr': 0.0005, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.0638
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8592
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.7926
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 128, 'dropout': 0.2} ... Loss: 3.0709
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 6, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8748
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.8309
#    -> Training: {'lr': 0.0001, 'batch_size': 16, 'n_layer': 2, 'n_embd': 32, 'dropout': 0.2} ... Loss: 3.9109
# Episode 100/100 complete. Epsilon: 0.10
#
# ========================================
# Optimization Finished in 66.23s
# Best Loss: 2.5571
# Best Config: {'lr': 0.005, 'batch_size': 32, 'n_layer': 4, 'n_embd': 64, 'dropout': 0.0}
# ========================================

# %% [markdown]
# In the end we are going to keep the basic Q-learning algorithm
